# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import table
import sklearn.metrics as metrics

# %%
with open("src/models/results/LG_16_labels.pkl", 'rb') as f:
    lg_labels = pickle.load(f)
    
with open("src/models/results/RF_16_labels.pkl", 'rb') as f:
    rf_labels = pickle.load(f)

with open("src/models/results/XGB_16_labels.pkl", 'rb') as f:
    xgb_labels = pickle.load(f)

# %%
prob_lg = lg_labels[2]

# %%
len(prob_lg)
# Out:
# 1302

# %%
prob_lg[:, 0]
# Out:
# array([0.00459583, 0.01317003, 0.01051753, ..., 0.00478898, 0.01896824,
#        0.00579968])

# %%
prob_lg[:, 30]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-91-e02131d92ff2> in <module>
# ----> 1 prob_lg[:, 30]
#
# IndexError: index 30 is out of bounds for axis 1 with size 16

# %%
lg_labels[0]
# Out:
# 7846     9
# 6577     8
# 5487     1
# 5795     9
# 5548    11
#         ..
# 8014     3
# 6767     8
# 2175    11
# 6665     8
# 6120     3
# Name: type, Length: 1302, dtype: int64

# %%
prob_lg = lg_labels[2]
fpr = dict()
tpr = dict()
roc_auc = dict()
for i in range(15):
    fpr[i], tpr[i], _ = metrics.roc_curve(lg_labels[0], prob_lg[:, i])
    roc_auc[i] = auc(fpr[i], tpr[i])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-87-647743e8d012> in <module>
#       4 roc_auc = dict()
#       5 for i in range(15):
# ----> 6     fpr[i], tpr[i], _ = metrics.roc_curve(lg_labels[0], prob_lg[:, i])
#       7     roc_auc[i] = auc(fpr[i], tpr[i])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     911
#     912     """
# --> 913     fps, tps, thresholds = _binary_clf_curve(
#     914         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     915
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     689     if not (y_type == "binary" or
#     690             (y_type == "multiclass" and pos_label is not None)):
# --> 691         raise ValueError("{0} format is not supported".format(y_type))
#     692
#     693     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %%
prob_lg = lg_labels[2]
fpr_lg_0, tpr_lg_0, threshold = metrics.roc_curve(lg_labels[0], prob_lg[:,0])
fpr_lg_1, tpr_lg_1, threshold = metrics.roc_curve(lg_labels[0], prob_lg[:,1])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-83-d95769023ddf> in <module>
#       1 prob_lg = lg_labels[2]
# ----> 2 fpr_lg_0, tpr_lg_0, threshold = metrics.roc_curve(lg_labels[0], prob_lg[:,0])
#       3 fpr_lg_1, tpr_lg_1, threshold = metrics.roc_curve(lg_labels[0], prob_lg[:,1])
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/utils/validation.py in inner_f(*args, **kwargs)
#      61             extra_args = len(args) - len(all_args)
#      62             if extra_args <= 0:
# ---> 63                 return f(*args, **kwargs)
#      64
#      65             # extra_args > 0
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in roc_curve(y_true, y_score, pos_label, sample_weight, drop_intermediate)
#     911
#     912     """
# --> 913     fps, tps, thresholds = _binary_clf_curve(
#     914         y_true, y_score, pos_label=pos_label, sample_weight=sample_weight)
#     915
#
# ~/opt/anaconda3/lib/python3.8/site-packages/sklearn/metrics/_ranking.py in _binary_clf_curve(y_true, y_score, pos_label, sample_weight)
#     689     if not (y_type == "binary" or
#     690             (y_type == "multiclass" and pos_label is not None)):
# --> 691         raise ValueError("{0} format is not supported".format(y_type))
#     692
#     693     check_consistent_length(y_true, y_score, sample_weight)
#
# ValueError: multiclass format is not supported

# %%
prob_rf = rf_labels[2]
fpr_rf_0, tpr_rf_0, threshold = metrics.roc_curve(rf_labels[0], prob_rf[:,0])
fpr_rf_1, tpr_rf_1, threshold = metrics.roc_curve(rf_labels[0], prob_rf[:,1])

# %%
prob_xgb = xgb_labels[2]
fpr_xgb_0, tpr_xgb_0, threshold = metrics.roc_curve(xgb_labels[0], prob_xgb[:,0])
fpr_xgb_1, tpr_xgb_1, threshold = metrics.roc_curve(xgb_labels[0], prob_xgb[:,1])

# %%
roc_auc0_lg = metrics.auc(fpr_lg_0, tpr_lg_0)
roc_auc1_lg = metrics.auc(fpr_lg_1, tpr_lg_1)

# %%
roc_auc0_rf = metrics.auc(fpr_rf_0, tpr_rf_0)
roc_auc1_rf = metrics.auc(fpr_rf_1, tpr_rf_1)

# %%
roc_auc0_xgb = metrics.auc(fpr_xgb_0, tpr_xgb_0)
roc_auc1_xgb = metrics.auc(fpr_xgb_1, tpr_xgb_1)

# %%
plt.title('J/P ROC')
plt.plot(fpr_lg_0, tpr_lg_0, 'b--', label = 'LG Class 0, AUC = %0.2f' % roc_auc0_lg)
plt.plot(fpr_lg_1, tpr_lg_1, 'b', label = 'LG Class 1, AUC = %0.2f' % roc_auc1_lg)

plt.plot(fpr_rf_0, tpr_rf_0, 'r--', label = 'RF Class 0, AUC = %0.2f' % roc_auc0_rf)
plt.plot(fpr_rf_1, tpr_rf_1, 'r', label = 'RF Class 1, AUC = %0.2f' % roc_auc1_rf)

plt.plot(fpr_xgb_0, tpr_xgb_0, 'g--', label = 'XGB Class 0, AUC = %0.2f' % roc_auc0_xgb)
plt.plot(fpr_xgb_1, tpr_xgb_1, 'g', label = 'XGB Class 1, AUC = %0.2f' % roc_auc1_xgb)

plt.legend(loc = 'lower right')
plt.plot([0, 1], [0, 1],'m--')
plt.xlim([0, 1])
plt.ylim([0, 1])
plt.ylabel('True Positive Rate')
plt.xlabel('False Positive Rate')
plt.rcParams["figure.figsize"] = (10,5)
plt.savefig('visualizations/roc/jp_roc.png', dpi=700)
plt.show()
