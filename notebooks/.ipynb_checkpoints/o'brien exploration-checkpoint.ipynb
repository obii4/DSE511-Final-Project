# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

# %%
#intial data load and num of rows and cols
data = pd.read_csv('~/Desktop/mbti_1.csv')
num_rows, num_cols = data.shape
print(f'There are {num_rows} rows and {num_cols} columns in the dataset')
# Out:
# There are 8675 rows and 2 columns in the dataset

# %%
data
# Out:
#       type                                              posts
# 0     INFJ  'http://www.youtube.com/watch?v=qsXHcwe3krw|||...
# 1     ENTP  'I'm finding the lack of me in these posts ver...
# 2     INTP  'Good one  _____   https://www.youtube.com/wat...
# 3     INTJ  'Dear INTP,   I enjoyed our conversation the o...
# 4     ENTJ  'You're fired.|||That's another silly misconce...
# ...    ...                                                ...
# 8670  ISFP  'https://www.youtube.com/watch?v=t8edHB_h908||...
# 8671  ENFP  'So...if this thread already exists someplace ...
# 8672  INTP  'So many questions when i do these things.  I ...
# 8673  INFP  'I am very conflicted right now when it comes ...
# 8674  INFP  'It has been too long since I have been on per...
#
# [8675 rows x 2 columns]

# %%
personalities = np.unique(np.array(data['type']))
personalities
# Out:
# array(['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP',
#        'INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP'],
#       dtype=object)

# %%
num_post = data.groupby(['type']).count()
num_post
# Out:
#       posts
# type
# ENFJ    190
# ENFP    675
# ENTJ    231
# ENTP    685
# ESFJ     42
# ESFP     48
# ESTJ     39
# ESTP     89
# INFJ   1470
# INFP   1832
# INTJ   1091
# INTP   1304
# ISFJ    166
# ISFP    271
# ISTJ    205
# ISTP    337

# %%
#num of post for each personality type
plt.bar(personalities, num_post['posts'],)
plt.xlabel('Personality types', size = 14)
plt.ylabel('No. of posts', size = 14)
plt.title('Total posts for each personality type')
plt.rcParams["figure.figsize"] = (15,10)

# %%
#visualize post for each personaility type

df = data

df['number of words/comment'] = df['posts'].apply(lambda x: len(x.split()))

sns.swarmplot("type", "number of words/comment", data = df, s = 2).set_title("Post length vs Personaility type")
plt.show()
# Out:
# /Users/chrisobrien/opt/anaconda3/envs/DSE511P1/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
def text_split(text):
    extroversion = text[text['type'].isin(['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP'])]
    extroversion = extroversion.replace(['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'ESFJ', 'ESFP', 'ESTJ', 'ESTP'], 
                                    [0, 0, 0, 0, 0, 0, 0, 0])
    introversion = text[text['type'].isin(['INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP'])]
    introversion = introversion.replace(['INFJ', 'INFP', 'INTJ', 'INTP', 'ISFJ', 'ISFP', 'ISTJ', 'ISTP'], 
                                    [1, 1, 1, 1, 1, 1, 1, 1])

    intuition = text[text['type'].isin(['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'INFJ', 'INFP', 'INTJ', 'INTP'])]
    intuition = intuition.replace(['ENFJ', 'ENFP', 'ENTJ', 'ENTP', 'INFJ', 'INFP', 'INTJ', 'INTP'], 
                                    [0, 0, 0, 0, 0, 0, 0, 0])
    sensing = text[text['type'].isin(['ISFJ', 'ISFP', 'ISTJ', 'ISTP','ESFJ', 'ESFP', 'ESTJ', 'ESTP'])]
    sensing = sensing.replace(['ISFJ', 'ISFP', 'ISTJ', 'ISTP','ESFJ', 'ESFP', 'ESTJ', 'ESTP'], 
                                    [1, 1, 1, 1, 1, 1, 1, 1])

    thinking = text[text['type'].isin(['ENTJ', 'ENTP','ESTJ', 'ESTP','INTJ', 'INTP', 'ISTJ', 'ISTP'])]
    thinking = thinking.replace(['ENTJ', 'ENTP','ESTJ', 'ESTP','INTJ', 'INTP', 'ISTJ', 'ISTP'], 
                                    [0, 0, 0, 0, 0, 0, 0, 0])
    feeling = text[text['type'].isin(['ENFJ', 'ENFP','ESFJ', 'ESFP', 'INFJ', 'INFP', 'ISFJ', 'ISFP'])]
    feeling = feeling.replace(['ENFJ', 'ENFP','ESFJ', 'ESFP', 'INFJ', 'INFP', 'ISFJ', 'ISFP'], 
                                    [1, 1, 1, 1, 1, 1, 1, 1])

    judging = text[text['type'].isin(['ENFJ','ENTJ', 'ESFJ', 'ESTJ', 'INFJ', 'INTJ', 'ISFJ', 'ISTJ'])]
    judging = judging.replace(['ENFJ','ENTJ', 'ESFJ', 'ESTJ', 'INFJ', 'INTJ', 'ISFJ', 'ISTJ'], 
                                    [0, 0, 0, 0, 0, 0, 0, 0])

    percieving = text[text['type'].isin(['ENFP', 'ENTP', 'ESFP', 'ESTP', 'INFP', 'INTP', 'ISFP', 'ISTP'])]
    percieving = percieving.replace(['ENFP', 'ENTP', 'ESFP', 'ESTP', 'INFP', 'INTP', 'ISFP', 'ISTP'], 
                                    [1, 1, 1, 1, 1, 1, 1, 1])
    
    EI = pd.concat([extroversion, introversion])
    NS = pd.concat([intuition, sensing])
    TF = pd.concat([thinking, feeling])
    JP = pd.concat([judging, percieving])
    
    return EI, NS, TF, JP

# %%
EI, NS, TF, JP = text_split(data)

# %%
N = 4
bottom = (len(EI.value_counts()[0]), len(NS.value_counts()[0]), len(TF.value_counts()[0]), len(JP.value_counts()[0]))
top = (len(EI.value_counts()[1]), len(NS.value_counts()[1]), len(TF.value_counts()[1]), len(JP.value_counts()[1]))
ind = np.arange(N)
width = 0.7   

p1 = plt.bar(ind, bottom, width, label="E, N, T, J")
p2 = plt.bar(ind, top, width, bottom=bottom, label="I, S, F, P") 

plt.title('Distribution accoss types indicators')
plt.ylabel('Count')
plt.xticks(ind, ('I / E',  'N / S', 'T / F', 'J / P',))
plt.legend()

plt.show()
